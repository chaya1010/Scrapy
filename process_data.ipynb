# %%
from IPython.display import display
import pandas as pd

# %%
df = pd.read_csv('data/link.csv')
df = df.Link
df = df.dropna()
Link = df.to_list()

# %%
for link in Link:
    link.replace('https://www.lazada.co.th/shop-','').replace('/','').split('-')
# Out:
# ['traditional', 'laptops']
